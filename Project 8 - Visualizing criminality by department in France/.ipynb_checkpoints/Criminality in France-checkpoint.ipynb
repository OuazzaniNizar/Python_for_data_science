# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 16, 8

# %%
df=pd.read_excel(xl,sheet_name='01')

xl=pd.ExcelFile("tableaux-4001-ts.xlsx")

 
for sheetName in (xl.sheet_names[3:]):
    df=pd.read_excel(xl,sheet_name=sheetName)
    try :
        df_annee=df
        for i in range(23):
            columns=[]
            columns=df.columns[2+i*12:14+i*12]
            #print(columns)
            columns.append(df.columns[0:2])
            #print(columns)
            #df_annee=df[columns]
            column_name="sum"+str(2018-i)
            df_annee[column_name]=df_annee[df.columns[2+i*12:14+i*12]].sum(axis=1)
            #dept=df.merge(df_annee[['Index',column_name]])
        transpose=df_annee[df_annee.columns[-23:].append(df_annee.columns[0:2])]
        df_dept=transpose.set_index('libellé index').T
        df_dept['dept']=sheetName
        df_final=pd.concat([df_final,df_dept],axis=0)
    except Exception:
        traceback.print_exc()
        
writer = pd.ExcelWriter('dept_crimi.xlsx')
df_final.to_excel(writer,'Sheet1')
writer.save()

# %% [markdown]
# # Analyzing the data

# %%
data=pd.read_excel('dept_crimi.xlsx',sheet_name='Sheet1')
data.head(5)
# Out:
#   dept annee  Règlements de compte entre malfaireurs  \
# 0   01  2018                                       0
# 1   01  2017                                       0
# 2   01  2016                                       0
# 3   01  2015                                       0
# 4   01  2014                                       0
#
#    Homicides pour voler et à l'occasion de vols  \
# 0                                             0
# 1                                             0
# 2                                             1
# 3                                             0
# 4                                             0
#
#    Homicides pour d'autres motifs  \
# 0                               4
# 1                               7
# 2                               3
# 3                               4
# 4                               6
#
#    Tentatives d'homicides pour voler et à l'occasion de vols  \
# 0                                                  1
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Tentatives homicides pour d'autres motifs  \
# 0                                         10
# 1                                         12
# 2                                         14
# 3                                          7
# 4                                          5
#
#    Coups et blessures volontaires suivis de mort  \
# 0                                              2
# 1                                              1
# 2                                              1
# 3                                              2
# 4                                              1
#
#    Autres coups et blessures volontaires criminels ou correctionnels  \
# 0                                               1565
# 1                                               1453
# 2                                               1431
# 3                                               1475
# 4                                               1424
#
#    Prises d'otages à l'occasion de vols  ...    Index non utilisé.2  \
# 0                                     1  ...                      0
# 1                                     0  ...                      0
# 2                                     2  ...                      0
# 3                                     2  ...                      0
# 4                                     0  ...                      0
#
#    Index non utilisé.3  \
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
#
#    Prix illicittes, publicité fausse et infractions aux règles de la concurrence  \
# 0                                                  3
# 1                                                  5
# 2                                                  3
# 3                                                 10
# 4                                                  9
#
#    Achats et ventes sans factures  \
# 0                               2
# 1                               1
# 2                               1
# 3                               5
# 4                               8
#
#    Infractions à l'exercice d'une profession règlementée  \
# 0                                                  8
# 1                                                  5
# 2                                                 14
# 3                                                  9
# 4                                                 19
#
#    Infractions au droit de l'urbanisme et de la construction  \
# 0                                                 36
# 1                                                 35
# 2                                                 34
# 3                                                 26
# 4                                                 26
#
#    Fraudes fiscales  Autres délits économiques et financiers  Autres délits  \
# 0                 2                                       14           1062
# 1                 3                                        9            889
# 2                 1                                       12            870
# 3                 8                                       13            987
# 4                 4                                       14            904
#
#    total
# 0  26683
# 1  25335
# 2  25197
# 3  26296
# 4  25414
#
# [5 rows x 110 columns]

# %%
#getting total criminality of the last 20 years
total_criminality = data.groupby('dept').sum().reset_index()
total_criminality['dept']=total_criminality['dept'].astype(str)
total_criminality.head()
# Out:
#   dept  Règlements de compte entre malfaireurs  \
# 0   01                                      15
# 1   02                                      16
# 2   03                                       8
# 3   04                                       7
# 4   05                                       2
#
#    Homicides pour voler et à l'occasion de vols  \
# 0                                            10
# 1                                            11
# 2                                             7
# 3                                             4
# 4                                             2
#
#    Homicides pour d'autres motifs  \
# 0                             129
# 1                             150
# 2                              82
# 3                              58
# 4                              29
#
#    Tentatives d'homicides pour voler et à l'occasion de vols  \
# 0                                                 13
# 1                                                 19
# 2                                                  9
# 3                                                  6
# 4                                                  7
#
#    Tentatives homicides pour d'autres motifs  \
# 0                                        174
# 1                                        182
# 2                                        129
# 3                                         61
# 4                                         59
#
#    Coups et blessures volontaires suivis de mort  \
# 0                                             39
# 1                                             50
# 2                                             23
# 3                                             15
# 4                                             11
#
#    Autres coups et blessures volontaires criminels ou correctionnels  \
# 0                                              23238
# 1                                              35481
# 2                                              14050
# 3                                               7191
# 4                                               5813
#
#    Prises d'otages à l'occasion de vols  Prises d'otages dans un autre but  \
# 0                                    20                                 16
# 1                                    23                                 16
# 2                                     9                                 15
# 3                                    12                                 14
# 4                                     9                                  9
#
#     ...    Index non utilisé.2  Index non utilisé.3  \
# 0   ...                     99                  100
# 1   ...                     99                  100
# 2   ...                     99                  100
# 3   ...                     99                  100
# 4   ...                     99                  100
#
#    Prix illicittes, publicité fausse et infractions aux règles de la concurrence  \
# 0                                                237
# 1                                                197
# 2                                                213
# 3                                                274
# 4                                                196
#
#    Achats et ventes sans factures  \
# 0                             212
# 1                             152
# 2                             203
# 3                             147
# 4                             129
#
#    Infractions à l'exercice d'une profession règlementée  \
# 0                                                270
# 1                                                190
# 2                                                263
# 3                                                210
# 4                                                174
#
#    Infractions au droit de l'urbanisme et de la construction  \
# 0                                                609
# 1                                                316
# 2                                                355
# 3                                                931
# 4                                                677
#
#    Fraudes fiscales  Autres délits économiques et financiers  Autres délits  \
# 0               170                                      505          15728
# 1               173                                      395          19559
# 2               157                                      412           9045
# 3               161                                      244           5021
# 4               123                                      205           4076
#
#     total
# 0  541570
# 1  580258
# 2  305529
# 3  179274
# 4  148891
#
# [5 rows x 109 columns]

# %% [markdown]
# ## Getting geographical data

# %% [markdown]
# ### Geographical data sources :
# - https://public.opendatasoft.com/explore/dataset/code-insee-postaux-geoflar/table/?flg=fr
# - https://www.data.gouv.fr/fr/datasets/contours-des-departements-francais-issus-d-openstreetmap/
# - https://www.data.gouv.fr/fr/datasets/correspondance-code-insee-code-postal/

# %%
import gdal
import geopandas
from shapely.geometry import Point

# %%
#Make sure to have all the three files departements-20180101 .shp .shx and .dbf in your directory 
#to get the additional fields (code insee, nom, nuts3, wikipedia, surf_km2)
map_df = geopandas.read_file("departements-20180101.shp",encoding='utf-8')
map_df.head(5)
# Out:
#   code_insee               nom  nuts3              wikipedia  surf_km2  \
# 0        974        La Réunion  FR940          fr:La Réunion    2505.0
# 1         11              Aude  FR811  fr:Aude (département)    6343.0
# 2         43       Haute-Loire  FR723         fr:Haute-Loire    5003.0
# 3         13  Bouches-du-Rhône  FR823    fr:Bouches-du-Rhône    5247.0
# 4         47    Lot-et-Garonne  FR614      fr:Lot-et-Garonne    5385.0
#
#                                             geometry
# 0  (POLYGON ((55.21642675688027 -21.0390353881033...
# 1  POLYGON ((1.68871505484248 43.27367866077702, ...
# 2  POLYGON ((3.082060451005325 45.28987507143973,...
# 3  (POLYGON ((4.23013639969375 43.46047351660123,...
# 4  POLYGON ((-0.1405839165134379 44.2264834087735...

# %%
map_df.plot()

# %% [markdown]
# ## Merge the criminality data and the geographical data

# %%
merged_map = pd.merge(map_df,total_criminality, how='left', left_on = 'code_insee', right_on = 'dept')
merged_map=merged_map[~merged_map['code_insee'].isin(['971','972','973','974','976'])]
merged_map=merged_map.dropna()
merged_map.head(5)
# Out:
#   code_insee               nom  nuts3                wikipedia  surf_km2  \
# 1         11              Aude  FR811    fr:Aude (département)    6343.0
# 2         43       Haute-Loire  FR723           fr:Haute-Loire    5003.0
# 3         13  Bouches-du-Rhône  FR823      fr:Bouches-du-Rhône    5247.0
# 4         47    Lot-et-Garonne  FR614        fr:Lot-et-Garonne    5385.0
# 5         23            Creuse  FR632  fr:Creuse (département)    5599.0
#
#                                             geometry dept  \
# 1  POLYGON ((1.68871505484248 43.27367866077702, ...   11
# 2  POLYGON ((3.082060451005325 45.28987507143973,...   43
# 3  (POLYGON ((4.23013639969375 43.46047351660123,...   13
# 4  POLYGON ((-0.1405839165134379 44.2264834087735...   47
# 5  POLYGON ((1.372541761655563 46.21671720881361,...   23
#
#    Règlements de compte entre malfaireurs  \
# 1                                    15.0
# 2                                     1.0
# 3                                   367.0
# 4                                     7.0
# 5                                     2.0
#
#    Homicides pour voler et à l'occasion de vols  \
# 1                                           8.0
# 2                                           4.0
# 3                                          62.0
# 4                                           5.0
# 5                                           3.0
#
#    Homicides pour d'autres motifs    ...      Index non utilisé.2  \
# 1                           139.0    ...                     99.0
# 2                            44.0    ...                     99.0
# 3                           856.0    ...                     99.0
# 4                            86.0    ...                     99.0
# 5                            27.0    ...                     99.0
#
#    Index non utilisé.3  \
# 1                100.0
# 2                100.0
# 3                100.0
# 4                100.0
# 5                100.0
#
#    Prix illicittes, publicité fausse et infractions aux règles de la concurrence  \
# 1                                              251.0
# 2                                              183.0
# 3                                              438.0
# 4                                              245.0
# 5                                              175.0
#
#    Achats et ventes sans factures  \
# 1                           245.0
# 2                           155.0
# 3                           306.0
# 4                           159.0
# 5                           191.0
#
#    Infractions à l'exercice d'une profession règlementée  \
# 1                                              251.0
# 2                                              159.0
# 3                                              976.0
# 4                                              252.0
# 5                                              178.0
#
#    Infractions au droit de l'urbanisme et de la construction  \
# 1                                              834.0
# 2                                              331.0
# 3                                             3185.0
# 4                                              312.0
# 5                                              322.0
#
#    Fraudes fiscales  Autres délits économiques et financiers  Autres délits  \
# 1             212.0                                    576.0        11805.0
# 2             136.0                                    244.0         5529.0
# 3             827.0                                   9290.0        91614.0
# 4             222.0                                    404.0        10281.0
# 5             130.0                                    235.0         3412.0
#
#        total
# 1   464940.0
# 2   150246.0
# 3  3966572.0
# 4   315851.0
# 5    73027.0
#
# [5 rows x 115 columns]

# %%
type(merged_map)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
fig, ax = plt.subplots(1, figsize=(30, 20))
vmin, vmax = merged_map["total"].max(), merged_map["total"].min()

merged_map.plot(column="total", cmap="plasma", linewidth=0.8, ax=ax)
ax.axis("off")
ax.set_title("Total of crimes committed in France \nin the last 20 years by department.", fontdict={"fontsize": "25", "fontweight" : "3"})
ax.annotate('Source: INSEE database.',xy=(0.1, .08),  xycoords='figure fraction',
            horizontalalignment='left', verticalalignment='top', fontsize=12, color='#555555')


sm = plt.cm.ScalarMappable(cmap="plasma", norm=plt.Normalize(vmin=vmin, vmax=vmax))
sm._A = []
cbar = fig.colorbar(sm)

            
fig.savefig("criminality_map_export.png", dpi=300)
